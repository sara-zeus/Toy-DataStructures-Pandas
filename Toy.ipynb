# %% [markdown]
# <a href="https://colab.research.google.com/github/sara-zeus/Toy-DataStructures-Pandas/blob/main/Toy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas.util.testing as tm

# %%
tm.N, tm.K= 15, 3

# %%
import numpy as np

# %%
np.random.seed(400)

# %%
tm.makeTimeDataFrame(freq='M').head()
# Out:
#                    A         B         C         D
# 2000-01-31  0.279215  1.953512 -0.155059  1.236610
# 2000-02-29  0.702225  0.245474  0.388573  0.242572
# 2000-03-31  1.058219  1.341931 -0.059635 -0.225837
# 2000-04-30 -0.771477 -0.532598  1.280917  0.111580
# 2000-05-31 -0.247793  1.617965  2.196822  0.030149

# %%
tm.makeTimeDataFrame().head()
# Out:
#                    A         B         C         D
# 2000-01-03  0.816527 -1.346740  0.613425 -0.055793
# 2000-01-04  0.134532  0.115165 -0.143099 -1.207904
# 2000-01-05 -0.511725 -0.207451  0.302009  0.251319
# 2000-01-06 -0.285263 -0.872629  2.087544  1.123055
# 2000-01-07 -0.387575  0.992558  1.314780 -0.351644

# %%
[i for i in dir(tm) if i.startswith('make')]
# Out:
# ['makeBoolIndex',
#  'makeCategoricalIndex',
#  'makeCustomDataframe',
#  'makeCustomIndex',
#  'makeDataFrame',
#  'makeDateIndex',
#  'makeFloatIndex',
#  'makeFloatSeries',
#  'makeIntIndex',
#  'makeIntervalIndex',
#  'makeMissingDataframe',
#  'makeMixedDataFrame',
#  'makeMultiIndex',
#  'makeNumericIndex',
#  'makeObjectSeries',
#  'makePeriodFrame',
#  'makePeriodIndex',
#  'makePeriodSeries',
#  'makeRangeIndex',
#  'makeStringIndex',
#  'makeStringSeries',
#  'makeTimeDataFrame',
#  'makeTimeSeries',
#  'makeTimedeltaIndex',
#  'makeUIntIndex',
#  'make_rand_series']
